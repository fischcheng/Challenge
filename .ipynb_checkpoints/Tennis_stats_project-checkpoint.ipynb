# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Check available columns:
ATP2017=pd.read_csv('./tennis_atp/atp_matches_2017.csv',index_col=False,usecols=range(49))
ATP2017.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
ATP2017[['tourney_name','winner_name','round']]
# Out:
#                      tourney_name                  winner_name round
# 0                        Brisbane              Grigor Dimitrov     F
# 1                        Brisbane              Grigor Dimitrov    SF
# 2                        Brisbane                Kei Nishikori    SF
# 3                        Brisbane                 Milos Raonic    QF
# 4                        Brisbane              Grigor Dimitrov    QF
# 5                        Brisbane                Kei Nishikori    QF
# 6                        Brisbane           Stanislas Wawrinka    QF
# 7                        Brisbane                 Milos Raonic   R16
# 8                        Brisbane                 Rafael Nadal   R16
# 9                        Brisbane                Dominic Thiem   R16
# 10                       Brisbane              Grigor Dimitrov   R16
# 11                       Brisbane              Jordan Thompson   R16
# 12                       Brisbane                Kei Nishikori   R16
# 13                       Brisbane                  Kyle Edmund   R16
# 14                       Brisbane           Stanislas Wawrinka   R16
# 15                       Brisbane  Diego Sebastian Schwartzman   R32
# 16                       Brisbane                Mischa Zverev   R32
# 17                       Brisbane                 Rafael Nadal   R32
# 18                       Brisbane                 Samuel Groth   R32
# 19                       Brisbane                Nicolas Mahut   R32
# 20                       Brisbane              Grigor Dimitrov   R32
# 21                       Brisbane                 David Ferrer   R32
# 22                       Brisbane              Jordan Thompson   R32
# 23                       Brisbane              Jared Donaldson   R32
# 24                       Brisbane                Lucas Pouille   R32
# 25                       Brisbane                  Kyle Edmund   R32
# 26                       Brisbane               Viktor Troicki   R32
# 27                        Chennai        Roberto Bautista Agut     F
# 28                        Chennai              Daniil Medvedev    SF
# 29                        Chennai        Roberto Bautista Agut    SF
# ...                           ...                          ...   ...
# 2370  Davis Cup WG R1: CZE vs AUS                  Jiri Vesely    RR
# 2371  Davis Cup WG R1: CZE vs AUS              Jordan Thompson    RR
# 2372  Davis Cup WG R1: ESP vs CRO                Franco Skugor    RR
# 2373  Davis Cup WG R1: ESP vs CRO        Roberto Bautista Agut    RR
# 2374  Davis Cup WG R1: ESP vs CRO        Roberto Bautista Agut    RR
# 2375  Davis Cup WG R1: ESP vs CRO          Pablo Carreno Busta    RR
# 2376  Davis Cup WG QF: FRA vs GBR                Lucas Pouille    RR
# 2377  Davis Cup WG QF: FRA vs GBR                Jeremy Chardy    RR
# 2378  Davis Cup WG QF: FRA vs GBR                 Daniel Evans    RR
# 2379  Davis Cup WG QF: FRA vs GBR                Jeremy Chardy    RR
# 2380  Davis Cup WG QF: ITA vs BEL                 Steve Darcis    RR
# 2381  Davis Cup WG QF: ITA vs BEL                 David Goffin    RR
# 2382  Davis Cup WG QF: ITA vs BEL                 David Goffin    RR
# 2383  Davis Cup WG QF: ITA vs BEL         Alessandro Giannessi    RR
# 2384  Davis Cup WG R1: JPN vs FRA              Richard Gasquet    RR
# 2385  Davis Cup WG R1: JPN vs FRA                 Gilles Simon    RR
# 2386  Davis Cup WG R1: JPN vs FRA                Nicolas Mahut    RR
# 2387  Davis Cup WG R1: JPN vs FRA            Yasutaka Uchiyama    RR
# 2029         Winston-Salem  Roberto Bautista Agut
# 2202               Us Open           Rafael Nadal

# %%
# Pull out all Grand Slam matches
ATP2017[ATP2017['draw_size']==128][['tourney_name','winner_name']].count() #698 matches
GrandSlamMatches=ATP2017[ATP2017['draw_size']==128]
FirstWeek=GrandSlamMatches[GrandSlamMatches['round'].str.contains("R")]

Wimby1stWeek=FirstWeek[FirstWeek['tourney_name']=='Wimbledon']
Wimby1stWeek_QuarterPlayers=FirstWeek[(FirstWeek['tourney_name']=='Wimbledon')&(FirstWeek['round']=='R16')][['winner_name','winner_id']]

Wimby1stWeek_R16Win=FirstWeek[(FirstWeek['tourney_name']=='Wimbledon')&(FirstWeek['round']=='R16')][['winner_name','winner_id']]
Wimby1stWeek_R16Los=FirstWeek[(FirstWeek['tourney_name']=='Wimbledon')&(FirstWeek['round']=='R16')][['loser_name','loser_id']]
QWlist=Wimby1stWeek_R16Win.winner_id.tolist()
QLlist=Wimby1stWeek_R16Los.loser_id.tolist()

# %%
QWlist
# Out:
# [104918, 105023, 104180, 105227, 105683, 103819, 104607, 104925]

# %%
QLlist
# Out:
# [105332, 104731, 104745, 105138, 100644, 105777, 106233, 105173]

# %%
Wimby1stWeek_R16Win
# Out:
#          winner_name  winner_id
# 1637     Andy Murray     104918
# 1638     Sam Querrey     105023
# 1639   Gilles Muller     104180
# 1640     Marin Cilic     105227
# 1641    Milos Raonic     105683
# 1642   Roger Federer     103819
# 1643   Tomas Berdych     104607
# 1644  Novak Djokovic     104925

# %%
Wimby1stWeek_R16Los
# Out:
#                  loser_name  loser_id
# 1637           Benoit Paire    105332
# 1638         Kevin Anderson    104731
# 1639           Rafael Nadal    104745
# 1640  Roberto Bautista Agut    105138
# 1641       Alexander Zverev    100644
# 1642        Grigor Dimitrov    105777
# 1643          Dominic Thiem    106233
# 1644       Adrian Mannarino    105173

# %%
Wimby1stWeek_R16WinStat[['w_svpt','winner_name']]
# Out:
#       w_svpt     winner_name
# 1525    74.0     Andy Murray
# 1536    99.0     Sam Querrey
# 1548    90.0   Gilles Muller
# 1556    88.0     Marin Cilic
# 1557   110.0    Milos Raonic
# 1572    36.0   Roger Federer
# 1580   111.0   Tomas Berdych
# 1588    33.0  Novak Djokovic
# 1589    66.0     Andy Murray
# 1594    93.0     Sam Querrey
# 1600   173.0   Gilles Muller
# 1604    93.0     Marin Cilic
# 1605   113.0    Milos Raonic
# 1612    78.0   Roger Federer
# 1616   113.0   Tomas Berdych
# 1620    60.0  Novak Djokovic
# 1621   118.0     Andy Murray
# 1623   141.0     Sam Querrey
# 1626    98.0   Gilles Muller
# 1628    84.0     Marin Cilic
# 1629    87.0    Milos Raonic
# 1632    88.0   Roger Federer
# 1634    75.0   Tomas Berdych
# 1636    89.0  Novak Djokovic
# 1637    99.0     Andy Murray
# 1638   173.0     Sam Querrey
# 1639   212.0   Gilles Muller
# 1640    78.0     Marin Cilic
# 1641   175.0    Milos Raonic
# 1642    75.0   Roger Federer
# 1643   141.0   Tomas Berdych
# 1644    93.0  Novak Djokovic

# %%
Wimby1stWeek_R16WinStat=Wimby1stWeek[Wimby1stWeek['winner_id'].isin(QWlist)]
Wimby1stWeek_R16WinStat=Wimby1stWeek[Wimby1stWeek['winner_id'].isin(QLlist)]
Wimby1stWeek_R16LosStat_win=Wimby1stWeek[Wimby1stWeek['winner_id'].isin(QLlist)].mean()                             
Wimby1stWeek_R16LosStat_los=Wimby1stWeek[Wimby1stWeek['loser_id'].isin(QLlist)].mean() #missing their stats in the R16 becausethey lost

# %%
Wimby1stWeek_R16WinStat.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
Wimby1stWeek_R16WinStat.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced', 'w_1st_percentage', 'w_1st_win_percentage',
#        'w_2nd_win_percentage'],
#       dtype='object')

# %%
# Calculate percentage
Wimby1stWeek_R16WinStat['w_1st_percentage']=Wimby1stWeek_R16WinStat['w_1stIn']/Wimby1stWeek_R16WinStat['w_svpt']
Wimby1stWeek_R16WinStat['w_1st_win_percentage']=Wimby1stWeek_R16WinStat['w_1stWon']/Wimby1stWeek_R16WinStat['w_1stIn']
Wimby1stWeek_R16WinStat['w_2nd_win_percentage']=Wimby1stWeek_R16WinStat['w_2ndWon']/(Wimby1stWeek_R16WinStat['w_svpt']-Wimby1stWeek_R16WinStat['w_1stIn'])
Wimby1stWeek_R16WinStat['w_bpSaved_perct']=Wimby1stWeek_R16WinStat['w_bpSaved']/(Wimby1stWeek_R16WinStat['w_bpFaced'])


Wimby1stWeek_R16LosStat['w_1st_percentage']=Wimby1stWeek_R16LosStat['w_1stIn']/Wimby1stWeek_R16LosStat['w_svpt']
Wimby1stWeek_R16LosStat['w_1st_Los_percentage']=Wimby1stWeek_R16LosStat['w_1stWon']/Wimby1stWeek_R16LosStat['w_1stIn']
Wimby1stWeek_R16LosStat['w_2nd_Los_percentage']=Wimby1stWeek_R16LosStat['w_2ndWon']/(Wimby1stWeek_R16LosStat['w_svpt']-Wimby1stWeek_R16LosStat['w_1stIn'])
Wimby1stWeek_R16LosStat['w_bpSaved_perct']=Wimby1stWeek_R16LosStat['w_bpSaved']/(Wimby1stWeek_R16LosStat['w_bpFaced'])
# Out:
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
ax1=Wimby1stWeek_R16WinStat[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].mean().plot(kind='bar') #svpt>> not percentage, but total serves

# %%
del Wimby1stWeek_R16WinStat['w_bpSaved_perct']
ax2=Wimby1stWeek_R16WinStat[['w_ace','w_df','w_bpSaved', 'w_bpFaced']].mean().plot(kind='bar')
# Out:
# /Users/yucheng/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Wimby1stWeek_R16LosStat_win.count()
# Out:
# tourney_id            24
# tourney_name          24
# surface               24
# draw_size             24
# tourney_level         24
# tourney_date          24
# match_num             24
# winner_id             24
# winner_seed           15
# winner_entry           0
# winner_name           24
# winner_hand           24
# winner_ht             24
# winner_ioc            24
# winner_age            24
# winner_rank           24
# winner_rank_points    24
# loser_id              24
# loser_seed             5
# loser_entry            0
# loser_name            24
# loser_hand            24
# loser_ht              19
# loser_ioc             24
# loser_age             24
# loser_rank            24
# loser_rank_points     24
# score                 24
# best_of               24
# round                 24
# minutes               24
# w_ace                 24
# w_df                  24
# w_svpt                24
# w_1stIn               24
# w_1stWon              24
# w_2ndWon              24
# w_SvGms               24
# w_bpSaved             24
# w_bpFaced             24
# l_ace                 24
# l_df                  24
# l_svpt                24
# l_1stIn               24
# l_1stWon              24
# l_2ndWon              24
# l_SvGms               24
# l_bpSaved             24
# l_bpFaced             24
# dtype: int64

# %%
Wimby1stWeek_R16LosStat_df=pd.DataFrame()

# %%
Wimby1stWeek_R16LosStat_df['w_1st_percentage']=(Wimby1stWeek_R16LosStat_win['w_1stIn']+Wimby1stWeek_R16LosStat_los['l_1stIn'])/(Wimby1stWeek_R16LosStat_win['w_svpt']+Wimby1stWeek_R16LosStat_los['l_svpt'])

# %%
# Quarter Final Loser stats, plot on the same plot
Wimby1stWeek_R16LosStat_dict={}
Wimby1stWeek_R16LosStat_dict['w_1st_percentage']=(Wimby1stWeek_R16LosStat_win['w_1stIn']+Wimby1stWeek_R16LosStat_los['l_1stIn'])/(Wimby1stWeek_R16LosStat_win['w_svpt']+Wimby1stWeek_R16LosStat_los['l_svpt'])
Wimby1stWeek_R16LosStat_dict['w_1st_win_percentage']=(Wimby1stWeek_R16LosStat_win['w_1stWon']+Wimby1stWeek_R16LosStat_los['l_1stWon'])/(Wimby1stWeek_R16LosStat_win['w_1stIn']+Wimby1stWeek_R16LosStat_los['l_1stIn'])
Wimby1stWeek_R16LosStat_dict['w_2nd_win_percentage']=(Wimby1stWeek_R16LosStat_win['w_2ndWon']+Wimby1stWeek_R16LosStat_los['l_2ndWon'])/((Wimby1stWeek_R16LosStat_win['w_svpt']+Wimby1stWeek_R16LosStat_los['l_svpt'])-(Wimby1stWeek_R16LosStat_win['w_1stIn']+Wimby1stWeek_R16LosStat_los['l_1stIn']))
Wimby1stWeek_R16LosStat_dict['w_bpSaved_perct']=(Wimby1stWeek_R16LosStat_win['w_bpSaved']+Wimby1stWeek_R16LosStat_los['l_bpSaved'])/(Wimby1stWeek_R16LosStat_win['w_bpFaced']+Wimby1stWeek_R16LosStat_los['l_bpFaced'])

Serving_percentage_R16Win=Wimby1stWeek_R16WinStat[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].mean() #svpt>> not percentage, but total serves
Serving_percentage_R16Win_std=Wimby1stWeek_R16WinStat[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].std()

Serving_percentage_R16Los_std=Wimby1stWeek_R16LosStat[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].std()



Wimby1stWeek_R16LosStat_dict['w_2nd_win_percentage']=(Wimby1stWeek_R16LosStat_win['w_2ndWon']+Wimby1stWeek_R16LosStat_los['l_2ndWon'])/((Wimby1stWeek_R16LosStat_win['w_svpt']+Wimby1stWeek_R16LosStat_los['l_svpt'])-(Wimby1stWeek_R16LosStat_win['w_1stIn']+Wimby1stWeek_R16LosStat_los['l_1stIn']))
Wimby1stWeek_R16WinStat_dict=Serving_percentage_R16Win.to_dict()
Wimby1stWeek_R16WinStat_std_dict=Serving_percentage_R16Win_std.to_dict()
Wimby1stWeek_R16LosStat_std_dict=Serving_percentage_R16Los_std.to_dict()

# %%
Wimby1stWeek_R16LosStat_std_dict.values()
# Out:
# dict_values([0.068427015116186096, 1.1279877210074441e-16, 2.2559754420148882e-16, 0.18895603657679533])

# %%
import seaborn as sns
sns.set(style="whitegrid")

width = 0.15       # the width of the bars

plt.bar(np.arange(len(Wimby1stWeek_R16LosStat_dict))-0.01, Wimby1stWeek_R16LosStat_dict.values(),width, align='center',yerr=Wimby1stWeek_R16LosStat_std_dict.values())
plt.bar(np.arange(len(Wimby1stWeek_R16WinStat_dict))+width+0.01, Wimby1stWeek_R16WinStat_dict.values(),width, align='center',yerr=Wimby1stWeek_R16WinStat_std_dict.values())
plt.xticks(range(len(Wimby1stWeek_R16LosStat_dict)), Wimby1stWeek_R16LosStat_dict.keys())
plt.ylabel('Percentage %')
plt.legend(['R16 Losers','R16 Winners'])
plt.title('2017 Wimbledon First 4 rounds average R16 Winner/Loser')
plt.show()

# %%
#Wimby1stWeek_R16LosStat_df[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].plot.bar(ax=ax1)
plt.bar(range(len(Wimby1stWeek_R16LosStat_df)), Wimby1stWeek_R16LosStat_df.values(), align='center')
# Out:
# <Container object of 4 artists>

# %%
Wimby1stWeek_R16LosStat_df[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-228-f51afa530ae8> in <module>()
# ----> 1 Wimby1stWeek_R16LosStat_df[['w_1st_percentage','w_1st_win_percentage','w_2nd_win_percentage','w_bpSaved_perct']].plot.bar()
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    2664         axes : matplotlib.AxesSubplot or np.array of them
#    2665         """
# -> 2666         return self(kind='bar', x=x, y=y, **kwds)
#    2667
#    2668     def barh(self, x=None, y=None, **kwds):
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
# -> 1694     plot_obj.generate()
#    1695     plot_obj.draw()
#    1696     return plot_obj.result
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     241     def generate(self):
#     242         self._args_adjust()
# --> 243         self._compute_plot_data()
#     244         self._setup_subplots()
#     245         self._make_plot()
#
# ~/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     350         if is_empty:
#     351             raise TypeError('Empty {0!r}: no numeric data to '
# --> 352                             'plot'.format(numeric_data.__class__.__name__))
#     353
#     354         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
Wimby1stWeek_R16LosStat
# Out:
#      tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 1530   2017-540    Wimbledon   Grass        128             G      20170703
# 1537   2017-540    Wimbledon   Grass        128             G      20170703
# 1541   2017-540    Wimbledon   Grass        128             G      20170703
# 1552   2017-540    Wimbledon   Grass        128             G      20170703
# 1564   2017-540    Wimbledon   Grass        128             G      20170703
# 1565   2017-540    Wimbledon   Grass        128             G      20170703
# 1573   2017-540    Wimbledon   Grass        128             G      20170703
# 1584   2017-540    Wimbledon   Grass        128             G      20170703
# 1591   2017-540    Wimbledon   Grass        128             G      20170703
# 1595   2017-540    Wimbledon   Grass        128             G      20170703
# 1597   2017-540    Wimbledon   Grass        128             G      20170703
# 1602   2017-540    Wimbledon   Grass        128             G      20170703
# 1608   2017-540    Wimbledon   Grass        128             G      20170703
# 1609   2017-540    Wimbledon   Grass        128             G      20170703
# 1573   7.0   4.0  107.0     62.0      45.0      20.0      0.0       10.0
# 1584  12.0   6.0  103.0     49.0      30.0      23.0      0.0        4.0
# 1591   7.0   5.0   90.0     50.0      36.0      18.0      0.0        3.0
# 1595  10.0   2.0   79.0     49.0      38.0      17.0      0.0        3.0
# 1597   8.0   3.0  104.0     68.0      45.0      14.0      0.0        4.0
# 1602   8.0   5.0  117.0     58.0      38.0      22.0      0.0       17.0
# 1608  11.0   4.0   76.0     48.0      36.0      12.0      0.0        2.0
# 1609   5.0   4.0   70.0     36.0      25.0      10.0      0.0        2.0
# 1613   3.0   2.0  147.0     93.0      62.0      27.0      0.0       13.0
# 1618   4.0   5.0  177.0    117.0      76.0      27.0      0.0       10.0
# 1622   4.0   2.0   81.0     42.0      33.0      19.0      0.0        2.0
# 1624   6.0   2.0  108.0     79.0      57.0      21.0      0.0        4.0
# 1625  13.0   6.0  103.0     71.0      49.0      11.0      0.0       11.0
# 1627   5.0   7.0  146.0     88.0      62.0      30.0      0.0        8.0
# 1630   1.0   5.0   92.0     53.0      33.0      13.0      0.0        8.0
# 1631   1.0   2.0   46.0     25.0      12.0       8.0      0.0        6.0
# 1633   4.0   3.0   87.0     40.0      29.0      24.0      0.0        4.0
# 1635  13.0   7.0  172.0    105.0      67.0      39.0      0.0       17.0
#
#      l_bpFaced
# 1530       9.0
# 1537       4.0
# 1541      13.0
# 1552      11.0
# 1564       3.0
# 1565       8.0
# 1573      14.0
# 1584      11.0
# 1591       7.0
# 1595       5.0
# 1597       9.0
# 1602      25.0
# 1608       6.0
# 1609       8.0
# 1613      18.0
# 1618      16.0
# 1622       5.0
# 1624       5.0
# 1625      15.0
# 1627      11.0
# 1630      15.0
# 1631      11.0
# 1633       9.0
# 1635      23.0
#
# [24 rows x 49 columns]

# %%
Wimby1stWeek_R16LosStat_win.mean()                        
Wimby1stWeek_R16LosStat_los.mean() #missing their stats in the R16 becausethey lost
# Out:
# draw_size             1.280000e+02
# tourney_date          2.017070e+07
# match_num             2.155000e+02
# winner_id             1.047978e+05
# winner_seed           8.750000e+00
# winner_ht             1.930000e+02
# winner_age            3.088912e+01
# winner_rank           1.150000e+01
# winner_rank_points    4.354375e+03
# loser_id              1.047216e+05
# loser_seed            1.060000e+01
# loser_ht              1.901250e+02
# loser_age             2.734463e+01
# loser_rank            2.387500e+01
# loser_rank_points     2.787625e+03
# best_of               5.000000e+00
# minutes               1.650000e+02
# w_ace                 1.550000e+01
# w_df                  2.625000e+00
# w_svpt                1.307500e+02
# w_1stIn               8.887500e+01
# w_1stWon              6.887500e+01
# w_2ndWon              2.337500e+01
# w_SvGms               0.000000e+00
# w_bpSaved             6.750000e+00
# w_bpFaced             8.375000e+00
# l_ace                 1.250000e+01
# l_df                  5.125000e+00
# l_svpt                1.216250e+02
# l_1stIn               7.937500e+01
# l_1stWon              5.837500e+01
# l_2ndWon              2.087500e+01
# l_SvGms               0.000000e+00
# l_bpSaved             5.375000e+00
# l_bpFaced             9.625000e+00
# dtype: float64

# %%
plt.figure()
